# %%
import numpy as np
import pandas as pd

from sklearn.model_selection import train_test_split

from sklearn.ensemble import ExtraTreesRegressor

from sklearn.preprocessing import RobustScaler 
from sklearn.preprocessing import StandardScaler

from sklearn.model_selection import GridSearchCV

from sklearn.metrics import mean_squared_error

# %% [markdown]
# # 🏆 XX diamonds
# ##  RSME = XX
# ## Score competi = XX

# %%
diamonds_1 = pd.read_csv('./data/diamonds_1.csv')
diamonds_2 = pd.read_csv('./data/diamonds_2.csv')
diamonds_3 = pd.read_csv('./data/diamonds_3.csv')
diamonds_4 = pd.read_csv('./data/diamonds_4.csv')
diamonds_5 = pd.read_csv('./data/diamonds_5.csv')
diamonds_6 = pd.read_csv('./data/diamonds_6.csv')
diamonds_7 = pd.read_csv('./data/diamonds_7.csv')

# %%
print(diamonds_1.shape)
print(diamonds_2.shape)
print(diamonds_3.shape)
print(diamonds_4.shape)
print(diamonds_5.shape)
print(diamonds_6.shape)
print(diamonds_7.shape)
# Out:
# (40439, 26)
# (40439, 9)
# (40439, 33)
# (40439, 7)
# (40439, 21)
# (40439, 19)
# (40439, 10)

# %%
X_1 = diamonds_1.drop('price', axis=1)
y_1 = diamonds_1['price']

X_2 = diamonds_2.drop('price', axis=1)
y_2 = diamonds_2['price']

X_3 = diamonds_3.drop('price', axis=1)
y_3 = diamonds_3['price']

X_4 = diamonds_4.drop('price', axis=1)
y_4 = diamonds_4['price']

X_5 = diamonds_5.drop('price', axis=1)
y_5 = diamonds_5['price']

X_6 = diamonds_6.drop('price', axis=1)
y_6 = diamonds_6['price']

X_7 = diamonds_7.drop('price', axis=1)
y_7 = diamonds_7['price']

# %% [markdown]
# # ⚠️ NO SCALER ⚠️

# %%
# X_1_train, X_1_test, y_1_train, y_1_test = train_test_split(X_1, y_1, test_size=0.2, random_state=42)
# X_2_train, X_2_test, y_2_train, y_2_test = train_test_split(X_2, y_2, test_size=0.2, random_state=42)
# X_3_train, X_3_test, y_3_train, y_3_test = train_test_split(X_3, y_3, test_size=0.2, random_state=42)
# X_4_train, X_4_test, y_4_train, y_4_test = train_test_split(X_4, y_4, test_size=0.2, random_state=42)
# X_5_train, X_5_test, y_5_train, y_5_test = train_test_split(X_5, y_5, test_size=0.2, random_state=42)
# X_6_train, X_6_test, y_6_train, y_6_test = train_test_split(X_6, y_6, test_size=0.2, random_state=42)
X_7_train, X_7_test, y_7_train, y_7_test = train_test_split(X_7, y_7, test_size=0.2, random_state=42)

# %%
model = ExtraTreesRegressor(max_depth=30, max_features='sqrt', min_samples_split=5,
                    n_estimators=150, random_state=42)
# Out:
#   Cell In[35], line 1
#     model = ExtraTreesRegressor('max_depth'= 30, 'max_features'= 'sqrt',
#                                 ^
# SyntaxError: expression cannot contain assignment, perhaps you meant "=="?

# %%
# model.fit(X_1_train, y_1_train)
# model.fit(X_2_train, y_2_train)
# model.fit(X_3_train, y_3_train)
# model.fit(X_4_train, y_4_train)
# model.fit(X_5_train, y_5_train)
# model.fit(X_6_train, y_6_train)
model.fit(X_7_train, y_7_train)
# Out:
# ExtraTreesRegressor(max_depth=30, max_features='sqrt', min_samples_split=5,
#                     n_estimators=150, random_state=42)

# %%
# pred_1 = model.predict(X_1_test)
# pred_2 = model.predict(X_2_test)
# pred_3 = model.predict(X_3_test)
# pred_4 = model.predict(X_4_test)
# pred_5 = model.predict(X_5_test)
# pred_6 = model.predict(X_6_test)
pred_7 = model.predict(X_7_test)

# %%
# rmse_1 = mean_squared_error(y_1_test, pred_1, squared=False)
# rmse_2 = mean_squared_error(y_2_test, pred_2, squared=False)
# rmse_3 = mean_squared_error(y_3_test, pred_3, squared=False)
# rmse_4 = mean_squared_error(y_4_test, pred_4, squared=False)
# rmse_5 = mean_squared_error(y_5_test, pred_5, squared=False)
# rmse_6 = mean_squared_error(y_6_test, pred_6, squared=False)
rmse_7 = mean_squared_error(y_7_test, pred_7, squared=False)
# Out:
# C:\Users\tete1\miniconda3\envs\jupyter_env\lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(

# %%
rmse_7
# Out:
# 555.1999697983089

# %%
print(rmse_1)
print(rmse_2)
print(rmse_3)
print(rmse_4)
print(rmse_5)
print(rmse_6)
print(rmse_7)
# Out:
# 587.9923600510391
# 541.2763794733395
# 627.6384220109115
# 568.578009149078
# 600.2508331786626
# 585.842847314503
# 540.0057399154472

# %% [markdown]
# ## GridSearch CV

# %%
model = ExtraTreesRegressor(random_state=42)

# %%
param_grid = {
    'n_estimators': [50, 100, 150],
    'max_depth': [None, 10, 20, 30],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4],
    'max_features': ['auto', 'sqrt', 'log2']
}

# %%
grid_search = GridSearchCV(estimator=model, 
                           param_grid=param_grid, 
                           scoring='neg_mean_squared_error', 
                           cv=5)

# %%
grid_search.fit(X_7_train, y_7_train)
# Out:
# C:\Users\tete1\miniconda3\envs\jupyter_env\lib\site-packages\sklearn\model_selection\_validation.py:542: FitFailedWarning:
# 540 fits failed out of a total of 1620.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 540 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\tete1\miniconda3\envs\jupyter_env\lib\site-packages\sklearn\model_selection\_validation.py", line 890, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\tete1\miniconda3\envs\jupyter_env\lib\site-packages\sklearn\base.py", line 1344, in wrapper
#     estimator._validate_params()
#   File "C:\Users\tete1\miniconda3\envs\jupyter_env\lib\site-packages\sklearn\base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Users\tete1\miniconda3\envs\jupyter_env\lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of ExtraTreesRegressor must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'sqrt', 'log2'} or None. Got 'auto' instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Users\tete1\miniconda3\envs\jupyter_env\lib\site-packages\sklearn\model_selection\_search.py:1051: UserWarning: One or more of the test scores are non-finite: [             nan              nan              nan              nan
#               nan              nan              nan              nan
#               nan              nan              nan              nan
#               nan              nan              nan              nan
#               nan              nan              nan              nan
#               nan              nan              nan              nan
#               nan              nan              nan -311522.17986365
#  -307024.46372817 -305371.98531563 -307385.06295929 -306979.78012408
#  -304609.43359697 -318396.06269634 -317037.7459711  -314603.57818015
#  -332731.95650887 -329091.08707929 -325634.24879658 -333885.51407915
#  -328373.32460147 -325538.8642075  -337969.87118019 -338274.7780869
#  -334873.49679221 -391888.87815097 -387507.31519328 -383490.04184671
#  -391888.87815097 -387507.31519328 -383490.04184671 -384280.98172088
#  -387590.24793023 -382788.32899074 -311522.17986365 -307024.46372817
#  -305371.98531563 -307385.06295929 -306979.78012408 -304609.43359697
#  -318396.06269634 -317037.7459711  -314603.57818015 -332731.95650887
#  -329091.08707929 -325634.24879658 -333885.51407915 -328373.32460147
#  -325538.8642075  -337969.87118019 -338274.7780869  -334873.49679221
#  -391888.87815097 -387507.31519328 -383490.04184671 -391888.87815097
#  -387507.31519328 -383490.04184671 -384280.98172088 -387590.24793023
#  -382788.32899074              nan              nan              nan
#               nan              nan              nan              nan
#               nan              nan              nan              nan
#               nan              nan              nan              nan
#               nan              nan              nan              nan
#               nan              nan              nan              nan
#               nan              nan              nan              nan
#  -652513.52720285 -633299.61599551 -625286.65146988 -646072.61886189
#  -636384.09340379 -635679.15894463 -658378.23767566 -645156.20184302
#  -643739.9688452  -654116.66584149 -643187.16075751 -641120.96821641
#  -672491.95575974 -649073.55795383 -645841.73409405 -683812.16913271
#  -658556.27844577 -655305.6996202  -705329.79644928 -683599.38579438
#  -674216.07469174 -705329.79644928 -683599.38579438 -674216.07469174
#  -716566.80706279 -680875.03053724 -678230.83193465 -652513.52720285
#  -633299.61599551 -625286.65146988 -646072.61886189 -636384.09340379
#  -635679.15894463 -658378.23767566 -645156.20184302 -643739.9688452
#  -654116.66584149 -643187.16075751 -641120.96821641 -672491.95575974
#  -649073.55795383 -645841.73409405 -683812.16913271 -658556.27844577
#  -655305.6996202  -705329.79644928 -683599.38579438 -674216.07469174
#  -705329.79644928 -683599.38579438 -674216.07469174 -716566.80706279
#  -680875.03053724 -678230.83193465              nan              nan
#               nan              nan              nan              nan
#               nan              nan              nan              nan
#               nan              nan              nan              nan
#               nan              nan              nan              nan
#               nan              nan              nan              nan
#               nan              nan              nan              nan
#               nan -308605.82601314 -307225.07296254 -304283.87392381
#  -313237.89388607 -309250.47520891 -306745.62862198 -319846.06309053
#  -318905.53083191 -319275.73098864 -331575.86364536 -329126.75994656
#  -327157.33609757 -326276.98333591 -327075.77007147 -326632.25665527
#  -339314.47565251 -336354.88118557 -333823.71242251 -400921.48231173
#  -398993.38439101 -388174.58606812 -400921.48231173 -398993.38439101
#  -388174.58606812 -385631.15843596 -384736.63136919 -382208.24552104
#  -308605.82601314 -307225.07296254 -304283.87392381 -313237.89388607
#  -309250.47520891 -306745.62862198 -319846.06309053 -318905.53083191
#  -319275.73098864 -331575.86364536 -329126.75994656 -327157.33609757
#  -326276.98333591 -327075.77007147 -326632.25665527 -339314.47565251
#  -336354.88118557 -333823.71242251 -400921.48231173 -398993.38439101
#  -388174.58606812 -400921.48231173 -398993.38439101 -388174.58606812
#  -385631.15843596 -384736.63136919 -382208.24552104              nan
#               nan              nan              nan              nan
#               nan              nan              nan              nan
#               nan              nan              nan              nan
#               nan              nan              nan              nan
#               nan              nan              nan              nan
#               nan              nan              nan              nan
#               nan              nan -313715.20464615 -309759.85114242
#  -307405.44763112 -305490.15910277 -304627.68706881 -302990.46177981
#  -317985.11360942 -315999.22299415 -314939.40126414 -331653.16517695
#  -326546.80665091 -322233.20644854 -336101.98117805 -327881.50849081
#  -324365.19294008 -338831.48341719 -336549.09355862 -333806.41642709
#  -390453.28989763 -385159.82963945 -382718.62139227 -390453.28989763
#  -385159.82963945 -382718.62139227 -387288.75095531 -389869.46540167
#  -385031.85525124 -313715.20464615 -309759.85114242 -307405.44763112
#  -305490.15910277 -304627.68706881 -302990.46177981 -317985.11360942
#  -315999.22299415 -314939.40126414 -331653.16517695 -326546.80665091
#  -322233.20644854 -336101.98117805 -327881.50849081 -324365.19294008
#  -338831.48341719 -336549.09355862 -333806.41642709 -390453.28989763
#  -385159.82963945 -382718.62139227 -390453.28989763 -385159.82963945
#  -382718.62139227 -387288.75095531 -389869.46540167 -385031.85525124]
#   warnings.warn(
# GridSearchCV(cv=5, estimator=ExtraTreesRegressor(random_state=42),
#              param_grid={'max_depth': [None, 10, 20, 30],
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'min_samples_leaf': [1, 2, 4],
#                          'min_samples_split': [2, 5, 10],
#                          'n_estimators': [50, 100, 150]},
#              scoring='neg_mean_squared_error')

# %%
best_params = grid_search.best_params_
best_estimator = grid_search.best_estimator_

# %%
print("Mejores hiperparámetros:", best_params)
print("Mejor estimador:", best_estimator)
# Out:
# Mejores hiperparámetros: {'max_depth': 30, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 150}
# Mejor estimador: ExtraTreesRegressor(max_depth=30, max_features='sqrt', min_samples_split=5,
#                     n_estimators=150, random_state=42)

# %% [markdown]
# ## 🏅 Winner: 7o diamonds RSME = 540.00

# %% [markdown]
# # ⚠️ ROBUST SCALER ⚠️

# %%
# robust_scaler = StandardScaler()
robust_scaler = RobustScaler()

# %%
# X_1_rob = robust_scaler.fit_transform(X_1)
# X_2_rob = robust_scaler.fit_transform(X_2)
# X_3_rob = robust_scaler.fit_transform(X_3)
# X_4_rob = robust_scaler.fit_transform(X_4)
# X_5_rob = robust_scaler.fit_transform(X_5)
# X_6_rob = robust_scaler.fit_transform(X_6)
X_7_rob = robust_scaler.fit_transform(X_7)

# %%
# X_1_rob_train, X_1_rob_test, y_1_rob_train, y_1_rob_test = train_test_split(X_1_rob, y_1, test_size=0.2, random_state=42)

# X_2_rob_train, X_2_rob_test, y_2_rob_train, y_2_rob_test = train_test_split(X_2_rob, y_2, test_size=0.2, random_state=42)
# X_3_rob_train, X_3_rob_test, y_3_rob_train, y_3_rob_test = train_test_split(X_3_rob, y_3, test_size=0.2, random_state=42)
# X_4_rob_train, X_4_rob_test, y_4_rob_train, y_4_rob_test = train_test_split(X_4_rob, y_4, test_size=0.2, random_state=42)
# X_5_rob_train, X_5_rob_test, y_5_rob_train, y_5_rob_test = train_test_split(X_5_rob, y_5, test_size=0.2, random_state=42)
# X_6_rob_train, X_6_rob_test, y_6_rob_train, y_6_rob_test = train_test_split(X_6_rob, y_6, test_size=0.2, random_state=42)
X_7_rob_train, X_7_rob_test, y_7_rob_train, y_7_rob_test = train_test_split(X_7_rob, y_7, test_size=0.2, random_state=42)

# %%
model = ExtraTreesRegressor(n_estimators=100, random_state=0)

# %%
# model.fit(X_1_rob_train, y_1_rob_train)
# model.fit(X_2_rob_train, y_2_rob_train)
# model.fit(X_3_rob_train, y_3_rob_train)
# model.fit(X_4_rob_train, y_4_rob_train)
# model.fit(X_5_rob_train, y_5_rob_train)
# model.fit(X_6_rob_train, y_6_rob_train)
model.fit(X_7_rob_train, y_7_rob_train)
# Out:
# ExtraTreesRegressor(random_state=0)

# %%
# pred_1_rob = model.predict(X_1_rob_test)
# pred_2_rob = model.predict(X_2_rob_test)
# pred_3_rob = model.predict(X_3_rob_test)
# pred_4_rob = model.predict(X_4_rob_test)
# pred_5_rob = model.predict(X_5_rob_test)
# pred_6_rob = model.predict(X_6_rob_test)
pred_7_rob = model.predict(X_7_rob_test)

# %%
# rmse_1_rob = mean_squared_error(y_1_rob_test, pred_1_rob, squared=False)
# rmse_2_rob = mean_squared_error(y_2_rob_test, pred_2_rob, squared=False)
# rmse_3_rob = mean_squared_error(y_3_rob_test, pred_3_rob, squared=False)
# rmse_4_rob = mean_squared_error(y_4_rob_test, pred_4_rob, squared=False)
# rmse_5_rob = mean_squared_error(y_5_rob_test, pred_5_rob, squared=False)
# rmse_6_rob = mean_squared_error(y_6_rob_test, pred_6_rob, squared=False)
rmse_7_rob = mean_squared_error(y_7_rob_test, pred_7_rob, squared=False)
# Out:
# C:\Users\tete1\miniconda3\envs\jupyter_env\lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(

# %%
rmse_7_rob
# Out:
# 538.9422997211841

# %%
# print(rmse_1_rob)
# print(rmse_2_rob)
# print(rmse_3_rob)
print(rmse_4_rob)
# print(rmse_5_rob)
# print(rmse_6_rob)
# print(rmse_7_rob)
# Out:
# 728.6786226474916

# %% [markdown]
# ## 🏅 Winner: 4o diamonds RSME = 728

# %%
diamonds_test = pd.read_csv('./data/diamonds_test.csv')

# %%
diamonds_test.drop('city', axis=1, inplace=True)

# %%
cut_map = {'Fair': 1,
           'Good': 2,
           'Very Good': 3,
           'Premium': 4,
           'Ideal': 5}

# %%
diamonds_test['cut'] = diamonds_test['cut'].map(cut_map)

# %%
clarity_map = {'I1': 1,
               'SI2': 2,
               'SI1': 3,
               'VS2': 4,
               'VS1': 5,
               'VVS2': 6,
               'VVS1': 7,
               'IF': 8}

# %%
diamonds_test['clarity'] = diamonds_test['clarity'].map(clarity_map)

# %%
color_map = {'J': 1,
             'I': 2,
             'H': 3,
             'G': 4,
             'F': 5,
             'E': 6,
             'D': 7}

# %%
diamonds_test['color'] = diamonds_test['color'].map(color_map)

# %%
diamonds_test.drop('id', axis= 1, inplace=True)

# %%
diamonds_test.head()
# Out:
#    carat  cut  color  clarity  depth  table     x     y     z
# 0   0.79    3      5        3   62.7   60.0  5.82  5.89  3.67
# 1   1.20    5      1        5   61.0   57.0  6.81  6.89  4.18
# 2   1.57    4      3        3   62.2   61.0  7.38  7.32  4.57
# 3   0.90    3      5        3   63.8   54.0  6.09  6.13  3.90
# 4   0.50    3      5        5   62.9   58.0  5.05  5.09  3.19

# %%
diamonds_test = diamonds_test[['carat', 'depth', 'table', 'x', 'y', 'z', 'cut', 'color', 'clarity']]

# %%
pred_test = model.predict(diamonds_test)
# Out:
# C:\Users\tete1\miniconda3\envs\jupyter_env\lib\site-packages\sklearn\base.py:486: UserWarning: X has feature names, but ExtraTreesRegressor was fitted without feature names
#   warnings.warn(

# %%
len(pred_test)
# Out:
# 13485

# %%
pred_test = pd.DataFrame(pred_test, columns=['price'])

# %%
pred_test['id'] = range(0, len(pred_test))

# %%
pred_test = pred_test[['id', 'price']]

# %%
pred_test.to_csv('./submissions/sub_ExtraTreesRegressor_540.csv', index=False)
